# %%
import pandas as pd
import numpy as np

# %%
teams = ['Atlanta Dream.csv', 'Chicago Sky.csv', 'Connecticut Sun.csv', 'Dallas Wings.csv', 'Indiana Fever.csv', 'Las Vegas Aces.csv', 'Los Angeles Sparks.csv', 'Minnesota Lynx.csv', 'New York Liberty.csv', 'Phoenix Mercury.csv', 'Seattle Storm.csv', 'Washington Mystics.csv']


teams_columns = ['PLAYER', '2023 TYPE', '2023', '2024 TYPE', '2024', '2025 TYPE', '2025', '2026 TYPE', '2026', '2027 TYPE', '2027']

teams_dict = {'Atlanta Dream':'team-data/Atlanta Dream.csv', 'Chicago Sky':'team-data/Chicago Sky.csv', 'Connecticut Sun':'team-data/Connecticut Sun.csv', 'Dallas Wings':'team-data/Dallas Wings.csv', 'Indiana Fever':'team-data/Indiana Fever.csv', 'Las Vegas Aces':'team-data/Las Vegas Aces.csv', 'Los Angeles Sparks':'team-data/Los Angeles Sparks.csv', 'Minnesota Lynx':'team-data/Minnesota Lynx.csv', 'New York Liberty':'team-data/New York Liberty.csv', 'Phoenix Mercury':'team-data/Phoenix Mercury.csv', 'Seattle Storm':'team-data/Seattle Storm.csv', 'Washington Mystics':'team-data/Washington Mystics.csv'   
}


df1 = pd.read_csv(teams_dict['Atlanta Dream'], usecols=teams_columns)
df1 = df1.iloc[:18].drop([15,16])
df1['Team'] = teams[0]
df2 = pd.read_csv(teams_dict['Chicago Sky'], usecols=teams_columns)
df2 = df2.iloc[:22].drop([19,20])
df2['Team'] = teams[1]
df3 = pd.read_csv(teams_dict['Connecticut Sun'], usecols=teams_columns)
df3 = df3.iloc[:20].drop([17,18])
df3['Team'] = teams[2]
df4 = pd.read_csv(teams_dict['Dallas Wings'], usecols=teams_columns)
df4 = df4.iloc[:16].drop([13,14])
df4['Team'] = teams[3]
df5 = pd.read_csv(teams_dict['Indiana Fever'], usecols=teams_columns)
df5 = df5.iloc[:20].drop([17,18])
df5['Team'] = teams[4]
df6 = pd.read_csv(teams_dict['Las Vegas Aces'], usecols=teams_columns)
df6 = df6.iloc[:17].drop([14,15])
df6['Team'] = teams[5]
df7 = pd.read_csv(teams_dict['Los Angeles Sparks'], usecols=teams_columns)
df7 = df7.iloc[:20].drop([17,18])
df7['Team'] = teams[6]
df8 = pd.read_csv(teams_dict['Minnesota Lynx'], usecols=teams_columns)
df8 = df8.iloc[:20].drop([17,18])
df8['Team'] = teams[7]
df9 = pd.read_csv(teams_dict['New York Liberty'], usecols=teams_columns)
df9 = df9.iloc[:19].drop([16,17])
df9['Team'] = teams[8]
df10 = pd.read_csv(teams_dict['Phoenix Mercury'], usecols=teams_columns)
df10 = df10.iloc[:17].drop([14,15])
df10['Team'] = teams[9]
df11 = pd.read_csv(teams_dict['Seattle Storm'], usecols=teams_columns)
df11 = df11.iloc[:21].drop([18,19])
df11['Team'] = teams[10]
df12 = pd.read_csv(teams_dict['Washington Mystics'], usecols=teams_columns)
df12 = df12.iloc[:20].drop([17,18])
df12['Team'] = teams[11]
df12
# Out:
#                       PLAYER 2023 TYPE       2023 2024 TYPE       2024
# 0         Elena Delle Donne          V  $234,350        UFA        NaN  \
# 1            Brittney Sykes          V  $190,000          V  $190,000
# 2              Natasha Cloud         V  $190,000        UFA        NaN
# 3        Myisha Hines-Allen          V  $175,100          V  $180,200
# 4              Ariel Atkins          V  $175,000        UFA        NaN
# 5   Shatori Walker-Kimbrough         V   $95,000          U   $97,850
# 6            Tianna Hawkins         TC   $74,305        UFA        NaN
# 7           Amanda Zahui B.         TC   $74,305        UFA        NaN
# 8             Shakira Austin         U   $73,584          U   $80,943
# 9                    Li Meng        TC   $62,285   Reserved        NaN
# 10            Alisia Jenkins        TC   $62,285        RFA        NaN
# 11            Jazmine Jones         TC   $62,285        RFA        NaN
# 12          Stephanie Jones         TC   $62,285   Reserved        NaN
# 13           Evina Westbrook        TC   $62,285   Reserved        NaN
# 14               Rui Machida       UFA        NaN       NaN        NaN
# 15            Jazmine Jones   Reserved        NaN       NaN        NaN
# 16           Klara Lundquist    SuspCE        NaN       NaN        NaN
# 19                  Cap Room       NaN  $287,466        NaN  $914,207
#
#    2025 TYPE         2025 2026 TYPE         2026 2027 TYPE         2027
# 0        NaN          NaN       NaN          NaN       NaN          NaN  \
# 1          V    $195,000        UFA          NaN       NaN          NaN
# 2        NaN          NaN       NaN          NaN       NaN          NaN
# 3        UFA          NaN       NaN          NaN       NaN          NaN
# 4        NaN          NaN       NaN          NaN       NaN          NaN
# 5        UFA          NaN       NaN          NaN       NaN          NaN
# 6        NaN          NaN       NaN          NaN       NaN          NaN
# 7        NaN          NaN       NaN          NaN       NaN          NaN
# 8        OPT     $91,981        RFA          NaN       NaN          NaN
# 9        NaN          NaN       NaN          NaN       NaN          NaN
# 10       NaN          NaN       NaN          NaN       NaN          NaN
# 11       NaN          NaN       NaN          NaN       NaN          NaN
# 12       NaN          NaN       NaN          NaN       NaN          NaN
# 13       NaN          NaN       NaN          NaN       NaN          NaN
# 14       NaN          NaN       NaN          NaN       NaN          NaN
# 15       NaN          NaN       NaN          NaN       NaN          NaN
# 16       NaN          NaN       NaN          NaN       NaN          NaN
# 19       NaN  $1,220,119        NaN  $1,552,300        NaN  $1,598,800
#
#                       Team
# 0   Washington Mystics.csv
# 1   Washington Mystics.csv
# 2   Washington Mystics.csv
# 3   Washington Mystics.csv
# 4   Washington Mystics.csv
# 5   Washington Mystics.csv
# 6   Washington Mystics.csv
# 7   Washington Mystics.csv
# 8   Washington Mystics.csv
# 9   Washington Mystics.csv
# 10  Washington Mystics.csv
# 11  Washington Mystics.csv
# 12  Washington Mystics.csv
# 13  Washington Mystics.csv
# 14  Washington Mystics.csv
# 15  Washington Mystics.csv
# 16  Washington Mystics.csv
# 19  Washington Mystics.csv

# %%
frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12]
df = pd.concat(frames)
df
# Out:
#                 PLAYER 2023 TYPE       2023 2024 TYPE       2024 2025 TYPE
# 0     Cheyenne Parker          V  $216,100          V  $200,000        UFA  \
# 1        Allisha Gray          V  $194,600          V  $185,000          V
# 2   Danielle Robinson          V  $155,000        UFA        NaN       NaN
# 3    Monique Billings          V  $145,000        UFA        NaN       NaN
# 4          Nia Coffey          V  $130,000        UFA        NaN       NaN
# ..                 ...       ...        ...       ...        ...       ...
# 13     Evina Westbrook        TC   $62,285   Reserved        NaN       NaN
# 14         Rui Machida       UFA        NaN       NaN        NaN       NaN
# 15      Jazmine Jones   Reserved        NaN       NaN        NaN       NaN
# 16     Klara Lundquist    SuspCE        NaN       NaN        NaN       NaN
# 19            Cap Room       NaN  $287,466        NaN  $914,207        NaN
#
#            2025 2026 TYPE         2026 2027 TYPE         2027
# 0           NaN       NaN          NaN       NaN          NaN  \
# 1     $190,000        UFA          NaN       NaN          NaN
# 2           NaN       NaN          NaN       NaN          NaN
# 3           NaN       NaN          NaN       NaN          NaN
# 4           NaN       NaN          NaN       NaN          NaN
# ..          ...       ...          ...       ...          ...
# 13          NaN       NaN          NaN       NaN          NaN
# 14          NaN       NaN          NaN       NaN          NaN
# 15          NaN       NaN          NaN       NaN          NaN
# 16          NaN       NaN          NaN       NaN          NaN
# 19  $1,220,119        NaN  $1,552,300        NaN  $1,598,800
#
#                       Team
# 0        Atlanta Dream.csv
# 1        Atlanta Dream.csv
# 2        Atlanta Dream.csv
# 3        Atlanta Dream.csv
# 4        Atlanta Dream.csv
# ..                     ...
# 13  Washington Mystics.csv
# 14  Washington Mystics.csv
# 15  Washington Mystics.csv
# 16  Washington Mystics.csv
# 19  Washington Mystics.csv
#
# [206 rows x 12 columns]

# %%
dftest = df[df['Team'] == 'Atlanta Dream.csv'].dropna(subset=['2023'])
dftest
# Out:
#                   PLAYER 2023 TYPE       2023 2024 TYPE       2024 2025 TYPE
# 0       Cheyenne Parker          V  $216,100          V  $200,000        UFA  \
# 1          Allisha Gray          V  $194,600          V  $185,000          V
# 2     Danielle Robinson          V  $155,000        UFA        NaN       NaN
# 3      Monique Billings          V  $145,000        UFA        NaN       NaN
# 4            Nia Coffey          V  $130,000        UFA        NaN       NaN
# 5         Aari McDonald          U   $78,586          R   $89,302        RFA
# 6         Asia Durr (AD)        TC   $74,305        RFA        NaN       NaN
# 7   Beatrice Mompremier         TC   $74,305        RFA        NaN       NaN
# 8           Rhyne Howard         U   $73,584          U   $80,943        OPT
# 9          Iliana Rupert         U   $67,634          U   $74,398        OPT
# 10           Naz Hillmon         U   $64,657          U   $71,124        OPT
# 11         Mikayla Pivec        TC   $62,285   Reserved        NaN       NaN
# 12          Lorela Cubaj        TC   $62,285   Reserved        NaN       NaN
# 17              Cap Room       NaN  $295,339        NaN  $762,433        NaN
#
#            2025 2026 TYPE         2026 2027 TYPE         2027
# 0           NaN       NaN          NaN       NaN          NaN  \
# 1     $190,000        UFA          NaN       NaN          NaN
# 2           NaN       NaN          NaN       NaN          NaN
# 3           NaN       NaN          NaN       NaN          NaN
# 4           NaN       NaN          NaN       NaN          NaN
# 5           NaN       NaN          NaN       NaN          NaN
# 6           NaN       NaN          NaN       NaN          NaN
# 7           NaN       NaN          NaN       NaN          NaN
# 8      $91,981        RFA          NaN       NaN          NaN
# 9      $84,543        RFA          NaN       NaN          NaN
# 10     $80,823        RFA          NaN       NaN          NaN
# 11          NaN       NaN          NaN       NaN          NaN
# 12          NaN       NaN          NaN       NaN          NaN
# 17  $1,059,753        NaN  $1,552,300        NaN  $1,598,800
#
#                  Team
# 0   Atlanta Dream.csv
# 1   Atlanta Dream.csv
# 2   Atlanta Dream.csv
# 3   Atlanta Dream.csv
# 4   Atlanta Dream.csv
# 5   Atlanta Dream.csv
# 6   Atlanta Dream.csv
# 7   Atlanta Dream.csv
# 8   Atlanta Dream.csv
# 9   Atlanta Dream.csv
# 10  Atlanta Dream.csv
# 11  Atlanta Dream.csv
# 12  Atlanta Dream.csv
# 17  Atlanta Dream.csv
